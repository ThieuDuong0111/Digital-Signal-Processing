# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import soundfile as sf
import os

# %%
import librosa
audio_data = 'download.mp3'
x , sr = librosa.load(audio_data)
print(type(x), type(sr))
print(x.shape, sr)

# Đọc file âm thanh male_voice.wav bằng librosa.load().

# x: Mảng NumPy chứa dữ liệu âm thanh dưới dạng sóng (waveform).
# sr: Tần số lấy mẫu (sampling rate), mặc định là 22050 Hz (trừ khi có chỉ định khác).
# In kiểu dữ liệu của x và sr.

# x là NumPy array (<class 'numpy.ndarray'>).
# sr là số nguyên (<class 'int'>).
# In kích thước của x và giá trị sr.

# x.shape là số lượng mẫu âm thanh. Nếu file có thời lượng 2 giây, thì số mẫu ≈ 22050 × 2 = 44100.
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (1800000,) 22050

# %%
import IPython.display as ipd
ipd.Audio(audio_data)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import matplotlib.pyplot as plt
import librosa.display

# Vẽ sóng âm với plt.plot()
plt.figure(figsize=(10, 4))
librosa.display.waveshow(x, sr=sr, color="blue")

# %% [markdown]
# <h3>Spectrogram</h3>
#
# A spectrogram is a visual way of representing the signal strength, or “loudness”, of a signal over time at various frequencies present in a particular waveform. Not only can one see whether there is more or less energy at, for example, 2 Hz vs 10 Hz, but one can also see how energy levels vary over time.
# A spectrogram is usually depicted as a heat map, i.e., as an image with the intensity shown by varying the color or brightness.
# We can display a spectrogram using. librosa.display.specshow.

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

# %% [markdown]
# <h3>Create an Audio Signal:</h3>

# %%
sr = 22050 # Sample rate (số mẫu trên giây)
T = 5.0    # Độ dài tín hiệu (giây)
t = np.linspace(0, T, int(T*sr), endpoint=False) # time variable
x = 0.5*np.sin(2*np.pi*800*t) # Sóng sine 220Hz

#Playing the audio
ipd.Audio(x, rate=sr) # load một NumPy array và phát âm thanh

#Saving the audio
sf.write('tone_220.wav', x, sr)

# Kết quả:
# Bạn sẽ nghe được âm thanh 220Hz kéo dài 5 giây.
